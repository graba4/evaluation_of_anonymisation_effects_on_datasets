# %%
import numpy as np
import pandas as pd
import time
import graphviz
import seaborn as sbn
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier

# %%
def Accuracy(predicted, truth):
    correct = 0
    for i in range(len(predicted)):
        if predicted[i]==truth.iloc[i]:
            correct +=1
    return correct/len(predicted)

# %%
ks = [1,2,4,8,16,32,64]

# %%
for k in ks:
    import keras
    from keras.models import Sequential
    from keras.layers import Dense
    from sklearn.preprocessing import StandardScaler
    from sklearn.model_selection import train_test_split
    import time
    census_data = pd.read_csv('ano-data/census/'+str(k)+'_census.csv',header = 0,sep=',',engine='python',na_values='?')
    census_test = pd.read_csv('ano-data/census/'+str(1)+'_census_test.csv',header = 0,sep=',',engine='python',na_values='?')
    
    data_feature = census_data.drop(columns=['income']).copy()
    data_label = census_data['income'].copy()

    test_feature = census_test.drop(columns=['income']).copy()
    test_label = census_test['income'].copy()

    for i in range(len(test_label)):
        test_label.loc[i]=str(test_label.loc[i]).strip('.')
        
    #Converting labels to 0-1
    for i in range(data_label.shape[0]):
        data_label.iloc[i]=int("<" in data_label.iloc[i])
    for i in range(test_label.shape[0]):
        test_label.iloc[i]=int("<" in test_label.iloc[i])
    
    anonimizeds = ['age', 'education-num','race','native-country','workclass','hours-per-week','sex']
    cols = data_feature.columns.values

    for col in cols:
        start = col.split('_')[0]
        if start not in anonimizeds:
            data_feature.drop(columns=[col],inplace=True)
            test_feature.drop(columns=[col],inplace=True)
            
###############################################################################################################
    sc = StandardScaler()
    data_feature = sc.fit_transform(data_feature)
    test_feature = sc.transform(test_feature)

    data_feature, val_feature, data_label, val_label = train_test_split(data_feature, data_label, test_size=0.15, random_state=42,stratify = data_label)

    SIZES = [32,64]
    times_scal = np.zeros(len(SIZES))
    accs_scal = np.zeros(len(SIZES))

    for i in range(len(SIZES)):
        classifier = Sequential()
        # Adding the input layer and the first hidden layer
        classifier.add(Dense(output_dim = SIZES[i], init = 'uniform', activation = 'relu', input_dim = data_feature.shape[1]))
        # Adding the second hidden layer
        classifier.add(Dense(output_dim = SIZES[i], init = 'uniform', activation = 'relu'))
        # Adding the output layer
        classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))

        classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
        clb = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=True)]
        start = time.time()
        classifier.fit(data_feature, data_label, batch_size = 8, nb_epoch = 100,validation_data=(val_feature,val_label),callbacks=clb)
        times_scal[i]=time.time()-start
        y_pred = classifier.predict(test_feature)
        y_pred = np.array([int(y>0.5) for y in y_pred])
        accs_scal[i]=Accuracy(y_pred,test_label)
    
    plt.figure()
    plt.plot(SIZES,times_scal,label = "Scaled")
    plt.xlabel("Size of one layer")
    plt.title("Training time (s)")
    plt.legend()
    plt.savefig("CensusIncome_NN_traintime_hpwsex"+str(k)+".png")
    
    plt.figure()
    plt.plot(SIZES,accs_scal*100,label = "Scaled")
    plt.xlabel("Size of one layer")
    plt.title("Accuracy (%)")
    plt.legend()
    plt.savefig("CensusIncome_NN_Accuracy_hpwsex"+str(k)+".png")
# Out:
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:49: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=61, units=32, kernel_initializer="uniform")`
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:51: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=32, kernel_initializer="uniform")`
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 7s 268us/step - loss: 0.4301 - acc: 0.7966 - val_loss: 0.4131 - val_acc: 0.8121
# Epoch 2/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.4082 - acc: 0.8088 - val_loss: 0.4100 - val_acc: 0.8078
# Epoch 3/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.4045 - acc: 0.8115 - val_loss: 0.4121 - val_acc: 0.8092
# Epoch 4/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.4022 - acc: 0.8128 - val_loss: 0.4060 - val_acc: 0.8115
# Epoch 5/100
# 27676/27676 [==============================] - 7s 244us/step - loss: 0.4005 - acc: 0.8128 - val_loss: 0.4043 - val_acc: 0.8121
# Epoch 6/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.3990 - acc: 0.8137 - val_loss: 0.4054 - val_acc: 0.8139
# Epoch 7/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.3974 - acc: 0.8137 - val_loss: 0.4071 - val_acc: 0.8115
# Epoch 8/100
# 27676/27676 [==============================] - 7s 246us/step - loss: 0.3960 - acc: 0.8155 - val_loss: 0.4088 - val_acc: 0.8102
# Epoch 9/100
# 27676/27676 [==============================] - 7s 260us/step - loss: 0.3951 - acc: 0.8138 - val_loss: 0.4093 - val_acc: 0.8106
# Epoch 10/100
# 27676/27676 [==============================] - 7s 271us/step - loss: 0.3946 - acc: 0.8148 - val_loss: 0.4063 - val_acc: 0.8104
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:49: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=61, units=64, kernel_initializer="uniform")`
# /home/pkovacs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:51: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=64, kernel_initializer="uniform")`
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 281us/step - loss: 0.4226 - acc: 0.8028 - val_loss: 0.4081 - val_acc: 0.8096
# Epoch 2/100
# 27676/27676 [==============================] - 7s 240us/step - loss: 0.4063 - acc: 0.8101 - val_loss: 0.4081 - val_acc: 0.8102
# Epoch 3/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.4036 - acc: 0.8100 - val_loss: 0.4058 - val_acc: 0.8094
# Epoch 4/100
# 27676/27676 [==============================] - 7s 239us/step - loss: 0.4005 - acc: 0.8122 - val_loss: 0.4055 - val_acc: 0.8115
# Epoch 5/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.3982 - acc: 0.8133 - val_loss: 0.4136 - val_acc: 0.8139
# Epoch 6/100
# 27676/27676 [==============================] - 7s 240us/step - loss: 0.3975 - acc: 0.8142 - val_loss: 0.4074 - val_acc: 0.8108
# Epoch 7/100
# 27676/27676 [==============================] - 7s 238us/step - loss: 0.3968 - acc: 0.8143 - val_loss: 0.4116 - val_acc: 0.8129
# Epoch 8/100
# 27676/27676 [==============================] - 7s 236us/step - loss: 0.3949 - acc: 0.8136 - val_loss: 0.4087 - val_acc: 0.8129
# Epoch 9/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.3948 - acc: 0.8164 - val_loss: 0.4097 - val_acc: 0.8162
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 7s 244us/step - loss: 0.4309 - acc: 0.7998 - val_loss: 0.4190 - val_acc: 0.8063
# Epoch 2/100
# 27676/27676 [==============================] - 6s 234us/step - loss: 0.4087 - acc: 0.8113 - val_loss: 0.4123 - val_acc: 0.8055
# Epoch 3/100
# 27676/27676 [==============================] - 7s 238us/step - loss: 0.4042 - acc: 0.8117 - val_loss: 0.4040 - val_acc: 0.8078
# Epoch 4/100
# 27676/27676 [==============================] - 7s 242us/step - loss: 0.4026 - acc: 0.8134 - val_loss: 0.4048 - val_acc: 0.8049
# Epoch 5/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.4010 - acc: 0.8155 - val_loss: 0.4052 - val_acc: 0.8035
# Epoch 6/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.3992 - acc: 0.8139 - val_loss: 0.4059 - val_acc: 0.8055
# Epoch 7/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.3978 - acc: 0.8166 - val_loss: 0.4055 - val_acc: 0.8057
# Epoch 8/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.3962 - acc: 0.8166 - val_loss: 0.4047 - val_acc: 0.8059
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 7s 260us/step - loss: 0.4247 - acc: 0.8023 - val_loss: 0.4135 - val_acc: 0.8070
# Epoch 2/100
# 27676/27676 [==============================] - 7s 253us/step - loss: 0.4083 - acc: 0.8112 - val_loss: 0.4123 - val_acc: 0.8051
# Epoch 3/100
# 27676/27676 [==============================] - 7s 242us/step - loss: 0.4047 - acc: 0.8115 - val_loss: 0.4038 - val_acc: 0.8084
# Epoch 4/100
# 27676/27676 [==============================] - 7s 261us/step - loss: 0.4012 - acc: 0.8137 - val_loss: 0.4045 - val_acc: 0.8057
# Epoch 5/100
# 27676/27676 [==============================] - 7s 250us/step - loss: 0.3991 - acc: 0.8147 - val_loss: 0.4044 - val_acc: 0.8051
# Epoch 6/100
# 27676/27676 [==============================] - 8s 285us/step - loss: 0.3975 - acc: 0.8153 - val_loss: 0.4031 - val_acc: 0.8088
# Epoch 7/100
# 27676/27676 [==============================] - 8s 285us/step - loss: 0.3965 - acc: 0.8147 - val_loss: 0.4055 - val_acc: 0.8047
# Epoch 8/100
# 27676/27676 [==============================] - 7s 249us/step - loss: 0.3942 - acc: 0.8166 - val_loss: 0.4029 - val_acc: 0.8057
# Epoch 9/100
# 27676/27676 [==============================] - 7s 260us/step - loss: 0.3934 - acc: 0.8160 - val_loss: 0.4069 - val_acc: 0.8053
# Epoch 10/100
# 27676/27676 [==============================] - 7s 258us/step - loss: 0.3916 - acc: 0.8163 - val_loss: 0.4085 - val_acc: 0.8086
# Epoch 11/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.3906 - acc: 0.8157 - val_loss: 0.4038 - val_acc: 0.8092
# Epoch 12/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.3894 - acc: 0.8194 - val_loss: 0.4043 - val_acc: 0.8084
# Epoch 13/100
# 27676/27676 [==============================] - 7s 252us/step - loss: 0.3887 - acc: 0.8177 - val_loss: 0.4057 - val_acc: 0.8068
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 277us/step - loss: 0.4332 - acc: 0.7965 - val_loss: 0.4093 - val_acc: 0.8121
# Epoch 2/100
# 27676/27676 [==============================] - 7s 253us/step - loss: 0.4106 - acc: 0.8091 - val_loss: 0.4120 - val_acc: 0.8106
# Epoch 3/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.4058 - acc: 0.8119 - val_loss: 0.4067 - val_acc: 0.8111
# Epoch 4/100
# 27676/27676 [==============================] - 7s 239us/step - loss: 0.4036 - acc: 0.8124 - val_loss: 0.4042 - val_acc: 0.8098
# Epoch 5/100
# 27676/27676 [==============================] - 7s 239us/step - loss: 0.4016 - acc: 0.8125 - val_loss: 0.4058 - val_acc: 0.8100
# Epoch 6/100
# 27676/27676 [==============================] - 7s 239us/step - loss: 0.4006 - acc: 0.8129 - val_loss: 0.4064 - val_acc: 0.8082
# Epoch 7/100
# 27676/27676 [==============================] - 7s 238us/step - loss: 0.3989 - acc: 0.8147 - val_loss: 0.4042 - val_acc: 0.8074
# Epoch 8/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.3972 - acc: 0.8149 - val_loss: 0.4027 - val_acc: 0.8074
# Epoch 9/100
# 27676/27676 [==============================] - 7s 240us/step - loss: 0.3956 - acc: 0.8159 - val_loss: 0.4059 - val_acc: 0.8094
# Epoch 10/100
# 27676/27676 [==============================] - 7s 238us/step - loss: 0.3947 - acc: 0.8150 - val_loss: 0.4056 - val_acc: 0.8086
# Epoch 11/100
# 27676/27676 [==============================] - 7s 242us/step - loss: 0.3939 - acc: 0.8168 - val_loss: 0.4042 - val_acc: 0.8119
# Epoch 12/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.3930 - acc: 0.8168 - val_loss: 0.4095 - val_acc: 0.8086
# Epoch 13/100
# 27676/27676 [==============================] - 7s 246us/step - loss: 0.3915 - acc: 0.8182 - val_loss: 0.4042 - val_acc: 0.8111
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 7s 261us/step - loss: 0.4266 - acc: 0.8012 - val_loss: 0.4092 - val_acc: 0.8106
# Epoch 2/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.4093 - acc: 0.8095 - val_loss: 0.4085 - val_acc: 0.8104
# Epoch 3/100
# 27676/27676 [==============================] - 7s 246us/step - loss: 0.4051 - acc: 0.8109 - val_loss: 0.4048 - val_acc: 0.8131
# Epoch 4/100
# 27676/27676 [==============================] - 7s 240us/step - loss: 0.4034 - acc: 0.8129 - val_loss: 0.4027 - val_acc: 0.8082
# Epoch 5/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.4011 - acc: 0.8134 - val_loss: 0.4046 - val_acc: 0.8123
# Epoch 6/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3991 - acc: 0.8132 - val_loss: 0.4012 - val_acc: 0.8102
# Epoch 7/100
# 27676/27676 [==============================] - 7s 253us/step - loss: 0.3967 - acc: 0.8134 - val_loss: 0.4049 - val_acc: 0.8104
# Epoch 8/100
# 27676/27676 [==============================] - 7s 244us/step - loss: 0.3956 - acc: 0.8147 - val_loss: 0.4073 - val_acc: 0.8074
# Epoch 9/100
# 27676/27676 [==============================] - 8s 275us/step - loss: 0.3949 - acc: 0.8163 - val_loss: 0.4051 - val_acc: 0.8113
# Epoch 10/100
# 27676/27676 [==============================] - 7s 249us/step - loss: 0.3938 - acc: 0.8149 - val_loss: 0.4053 - val_acc: 0.8125
# Epoch 11/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.3918 - acc: 0.8162 - val_loss: 0.4067 - val_acc: 0.8074
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.4310 - acc: 0.7990 - val_loss: 0.4124 - val_acc: 0.8063
# Epoch 2/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.4094 - acc: 0.8100 - val_loss: 0.4085 - val_acc: 0.8041
# Epoch 3/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.4058 - acc: 0.8120 - val_loss: 0.4179 - val_acc: 0.8047
# Epoch 4/100
# 27676/27676 [==============================] - 7s 246us/step - loss: 0.4033 - acc: 0.8138 - val_loss: 0.4129 - val_acc: 0.8057
# Epoch 5/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.4014 - acc: 0.8132 - val_loss: 0.4108 - val_acc: 0.8074
# Epoch 6/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.3992 - acc: 0.8149 - val_loss: 0.4083 - val_acc: 0.8063
# Epoch 7/100
# 27676/27676 [==============================] - 7s 245us/step - loss: 0.3981 - acc: 0.8159 - val_loss: 0.4094 - val_acc: 0.8074
# Epoch 8/100
# 27676/27676 [==============================] - 7s 246us/step - loss: 0.3970 - acc: 0.8154 - val_loss: 0.4077 - val_acc: 0.8051
# Epoch 9/100
# 27676/27676 [==============================] - 7s 258us/step - loss: 0.3960 - acc: 0.8168 - val_loss: 0.4071 - val_acc: 0.8057
# Epoch 10/100
# 27676/27676 [==============================] - 7s 266us/step - loss: 0.3954 - acc: 0.8166 - val_loss: 0.4080 - val_acc: 0.8059
# Epoch 11/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.3937 - acc: 0.8171 - val_loss: 0.4106 - val_acc: 0.8014
# Epoch 12/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.3927 - acc: 0.8175 - val_loss: 0.4104 - val_acc: 0.8063
# Epoch 13/100
# 27676/27676 [==============================] - 7s 262us/step - loss: 0.3919 - acc: 0.8168 - val_loss: 0.4065 - val_acc: 0.8066
# Epoch 14/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.3913 - acc: 0.8176 - val_loss: 0.4093 - val_acc: 0.8051
# Epoch 15/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3906 - acc: 0.8192 - val_loss: 0.4094 - val_acc: 0.8070
# Epoch 16/100
# 27676/27676 [==============================] - 7s 252us/step - loss: 0.3901 - acc: 0.8186 - val_loss: 0.4083 - val_acc: 0.8041
# Epoch 17/100
# 27676/27676 [==============================] - 7s 241us/step - loss: 0.3888 - acc: 0.8178 - val_loss: 0.4082 - val_acc: 0.8094
# Epoch 18/100
# 27676/27676 [==============================] - 7s 242us/step - loss: 0.3886 - acc: 0.8195 - val_loss: 0.4094 - val_acc: 0.8074
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.4275 - acc: 0.8012 - val_loss: 0.4113 - val_acc: 0.8084
# Epoch 2/100
# 27676/27676 [==============================] - 7s 244us/step - loss: 0.4089 - acc: 0.8087 - val_loss: 0.4074 - val_acc: 0.8080
# Epoch 3/100
# 27676/27676 [==============================] - 7s 243us/step - loss: 0.4049 - acc: 0.8124 - val_loss: 0.4059 - val_acc: 0.8100
# Epoch 4/100
# 27676/27676 [==============================] - 7s 246us/step - loss: 0.4029 - acc: 0.8121 - val_loss: 0.4070 - val_acc: 0.8068
# Epoch 5/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.4002 - acc: 0.8143 - val_loss: 0.4107 - val_acc: 0.8066
# Epoch 6/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.3975 - acc: 0.8153 - val_loss: 0.4132 - val_acc: 0.8078
# Epoch 7/100
# 27676/27676 [==============================] - 7s 253us/step - loss: 0.3957 - acc: 0.8141 - val_loss: 0.4115 - val_acc: 0.8051
# Epoch 8/100
# 27676/27676 [==============================] - 7s 264us/step - loss: 0.3948 - acc: 0.8156 - val_loss: 0.4088 - val_acc: 0.8078
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 280us/step - loss: 0.4307 - acc: 0.7982 - val_loss: 0.4147 - val_acc: 0.8068
# Epoch 2/100
# 27676/27676 [==============================] - 7s 244us/step - loss: 0.4102 - acc: 0.8098 - val_loss: 0.4125 - val_acc: 0.8037
# Epoch 3/100
# 27676/27676 [==============================] - 7s 244us/step - loss: 0.4064 - acc: 0.8120 - val_loss: 0.4116 - val_acc: 0.8061
# Epoch 4/100
# 27676/27676 [==============================] - 7s 266us/step - loss: 0.4043 - acc: 0.8141 - val_loss: 0.4115 - val_acc: 0.8082
# Epoch 5/100
# 27676/27676 [==============================] - 8s 284us/step - loss: 0.4026 - acc: 0.8152 - val_loss: 0.4125 - val_acc: 0.8074
# Epoch 6/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.4015 - acc: 0.8149 - val_loss: 0.4106 - val_acc: 0.8053
# Epoch 7/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.4001 - acc: 0.8159 - val_loss: 0.4101 - val_acc: 0.8074
# Epoch 8/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3988 - acc: 0.8159 - val_loss: 0.4100 - val_acc: 0.8098
# Epoch 9/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.3979 - acc: 0.8157 - val_loss: 0.4101 - val_acc: 0.8078
# Epoch 10/100
# 27676/27676 [==============================] - 7s 252us/step - loss: 0.3974 - acc: 0.8160 - val_loss: 0.4088 - val_acc: 0.8098
# Epoch 11/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3961 - acc: 0.8172 - val_loss: 0.4063 - val_acc: 0.8102
# Epoch 12/100
# 27676/27676 [==============================] - 7s 250us/step - loss: 0.3950 - acc: 0.8164 - val_loss: 0.4133 - val_acc: 0.8113
# Epoch 13/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3947 - acc: 0.8189 - val_loss: 0.4132 - val_acc: 0.8086
# Epoch 14/100
# 27676/27676 [==============================] - 7s 250us/step - loss: 0.3933 - acc: 0.8187 - val_loss: 0.4093 - val_acc: 0.8102
# Epoch 15/100
# 27676/27676 [==============================] - 7s 264us/step - loss: 0.3929 - acc: 0.8186 - val_loss: 0.4106 - val_acc: 0.8072
# Epoch 16/100
# 27676/27676 [==============================] - 7s 270us/step - loss: 0.3916 - acc: 0.8185 - val_loss: 0.4090 - val_acc: 0.8061
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 305us/step - loss: 0.4267 - acc: 0.8005 - val_loss: 0.4140 - val_acc: 0.8072
# Epoch 2/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.4101 - acc: 0.8118 - val_loss: 0.4187 - val_acc: 0.8027
# Epoch 3/100
# 27676/27676 [==============================] - 8s 287us/step - loss: 0.4069 - acc: 0.8121 - val_loss: 0.4186 - val_acc: 0.8045
# Epoch 4/100
# 27676/27676 [==============================] - 7s 267us/step - loss: 0.4041 - acc: 0.8127 - val_loss: 0.4095 - val_acc: 0.8072
# Epoch 5/100
# 27676/27676 [==============================] - 7s 258us/step - loss: 0.4029 - acc: 0.8132 - val_loss: 0.4096 - val_acc: 0.8051
# Epoch 6/100
# 27676/27676 [==============================] - 7s 259us/step - loss: 0.4006 - acc: 0.8152 - val_loss: 0.4081 - val_acc: 0.8037
# Epoch 7/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3987 - acc: 0.8145 - val_loss: 0.4082 - val_acc: 0.8063
# Epoch 8/100
# 27676/27676 [==============================] - 7s 254us/step - loss: 0.3976 - acc: 0.8166 - val_loss: 0.4084 - val_acc: 0.8070
# Epoch 9/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.3959 - acc: 0.8145 - val_loss: 0.4057 - val_acc: 0.8076
# Epoch 10/100
# 27676/27676 [==============================] - 7s 252us/step - loss: 0.3949 - acc: 0.8168 - val_loss: 0.4122 - val_acc: 0.8014
# Epoch 11/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.3943 - acc: 0.8157 - val_loss: 0.4058 - val_acc: 0.8096
# Epoch 12/100
# 27676/27676 [==============================] - 7s 254us/step - loss: 0.3927 - acc: 0.8170 - val_loss: 0.4089 - val_acc: 0.8068
# Epoch 13/100
# 27676/27676 [==============================] - 7s 253us/step - loss: 0.3918 - acc: 0.8180 - val_loss: 0.4085 - val_acc: 0.8037
# Epoch 14/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.3908 - acc: 0.8184 - val_loss: 0.4119 - val_acc: 0.8066
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 272us/step - loss: 0.4336 - acc: 0.7975 - val_loss: 0.4236 - val_acc: 0.8012
# Epoch 2/100
# 27676/27676 [==============================] - 7s 261us/step - loss: 0.4118 - acc: 0.8095 - val_loss: 0.4238 - val_acc: 0.8020
# Epoch 3/100
# 27676/27676 [==============================] - 7s 261us/step - loss: 0.4079 - acc: 0.8101 - val_loss: 0.4199 - val_acc: 0.8029
# Epoch 4/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.4056 - acc: 0.8118 - val_loss: 0.4168 - val_acc: 0.8039
# Epoch 5/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.4041 - acc: 0.8121 - val_loss: 0.4150 - val_acc: 0.8049
# Epoch 6/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.4025 - acc: 0.8145 - val_loss: 0.4194 - val_acc: 0.8020
# Epoch 7/100
# 27676/27676 [==============================] - 7s 252us/step - loss: 0.4015 - acc: 0.8138 - val_loss: 0.4143 - val_acc: 0.8043
# Epoch 8/100
# 27676/27676 [==============================] - 7s 248us/step - loss: 0.4009 - acc: 0.8145 - val_loss: 0.4205 - val_acc: 0.8014
# Epoch 9/100
# 27676/27676 [==============================] - 7s 248us/step - loss: 0.4000 - acc: 0.8156 - val_loss: 0.4142 - val_acc: 0.8041
# Epoch 10/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.3991 - acc: 0.8145 - val_loss: 0.4156 - val_acc: 0.8078
# Epoch 11/100
# 27676/27676 [==============================] - 7s 248us/step - loss: 0.3982 - acc: 0.8167 - val_loss: 0.4134 - val_acc: 0.8025
# Epoch 12/100
# 27676/27676 [==============================] - 7s 249us/step - loss: 0.3973 - acc: 0.8168 - val_loss: 0.4166 - val_acc: 0.8010
# Epoch 13/100
# 27676/27676 [==============================] - 7s 248us/step - loss: 0.3972 - acc: 0.8171 - val_loss: 0.4139 - val_acc: 0.8008
# Epoch 14/100
# 27676/27676 [==============================] - 7s 247us/step - loss: 0.3961 - acc: 0.8171 - val_loss: 0.4138 - val_acc: 0.8055
# Epoch 15/100
# 27676/27676 [==============================] - 7s 250us/step - loss: 0.3960 - acc: 0.8175 - val_loss: 0.4141 - val_acc: 0.8049
# Epoch 16/100
# 27676/27676 [==============================] - 8s 294us/step - loss: 0.3949 - acc: 0.8177 - val_loss: 0.4138 - val_acc: 0.8043
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 300us/step - loss: 0.4287 - acc: 0.8010 - val_loss: 0.4229 - val_acc: 0.8014
# Epoch 2/100
# 27676/27676 [==============================] - 7s 256us/step - loss: 0.4119 - acc: 0.8085 - val_loss: 0.4218 - val_acc: 0.8029
# Epoch 3/100
# 27676/27676 [==============================] - 8s 273us/step - loss: 0.4084 - acc: 0.8092 - val_loss: 0.4208 - val_acc: 0.8027
# Epoch 4/100
# 27676/27676 [==============================] - 8s 288us/step - loss: 0.4063 - acc: 0.8113 - val_loss: 0.4195 - val_acc: 0.8047
# Epoch 5/100
# 27676/27676 [==============================] - 7s 270us/step - loss: 0.4039 - acc: 0.8122 - val_loss: 0.4170 - val_acc: 0.8020
# Epoch 6/100
# 27676/27676 [==============================] - 7s 271us/step - loss: 0.4027 - acc: 0.8133 - val_loss: 0.4146 - val_acc: 0.8051
# Epoch 7/100
# 27676/27676 [==============================] - 7s 254us/step - loss: 0.4016 - acc: 0.8131 - val_loss: 0.4148 - val_acc: 0.8037
# Epoch 8/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.3999 - acc: 0.8152 - val_loss: 0.4134 - val_acc: 0.8051
# Epoch 9/100
# 27676/27676 [==============================] - 8s 281us/step - loss: 0.3987 - acc: 0.8137 - val_loss: 0.4147 - val_acc: 0.8029
# Epoch 10/100
# 27676/27676 [==============================] - 8s 279us/step - loss: 0.3979 - acc: 0.8157 - val_loss: 0.4121 - val_acc: 0.8051
# Epoch 11/100
# 27676/27676 [==============================] - 8s 294us/step - loss: 0.3963 - acc: 0.8160 - val_loss: 0.4148 - val_acc: 0.8059
# Epoch 12/100
# 27676/27676 [==============================] - 7s 254us/step - loss: 0.3956 - acc: 0.8157 - val_loss: 0.4155 - val_acc: 0.8047
# Epoch 13/100
# 27676/27676 [==============================] - 7s 251us/step - loss: 0.3940 - acc: 0.8159 - val_loss: 0.4154 - val_acc: 0.8066
# Epoch 14/100
# 27676/27676 [==============================] - 7s 252us/step - loss: 0.3934 - acc: 0.8166 - val_loss: 0.4137 - val_acc: 0.8045
# Epoch 15/100
# 27676/27676 [==============================] - 7s 262us/step - loss: 0.3924 - acc: 0.8168 - val_loss: 0.4138 - val_acc: 0.8063
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 297us/step - loss: 0.4332 - acc: 0.7967 - val_loss: 0.4145 - val_acc: 0.7977
# Epoch 2/100
# 27676/27676 [==============================] - 8s 276us/step - loss: 0.4154 - acc: 0.8060 - val_loss: 0.4084 - val_acc: 0.8104
# Epoch 3/100
# 27676/27676 [==============================] - 7s 271us/step - loss: 0.4118 - acc: 0.8072 - val_loss: 0.4070 - val_acc: 0.8088
# Epoch 4/100
# 27676/27676 [==============================] - 8s 272us/step - loss: 0.4093 - acc: 0.8086 - val_loss: 0.4068 - val_acc: 0.8115
# Epoch 5/100
# 27676/27676 [==============================] - 9s 326us/step - loss: 0.4083 - acc: 0.8090 - val_loss: 0.4075 - val_acc: 0.8080
# Epoch 6/100
# 27676/27676 [==============================] - 8s 278us/step - loss: 0.4068 - acc: 0.8098 - val_loss: 0.4050 - val_acc: 0.8092
# Epoch 7/100
# 27676/27676 [==============================] - 8s 284us/step - loss: 0.4055 - acc: 0.8124 - val_loss: 0.4053 - val_acc: 0.8098
# Epoch 8/100
# 27676/27676 [==============================] - 7s 269us/step - loss: 0.4050 - acc: 0.8093 - val_loss: 0.4063 - val_acc: 0.8094
# Epoch 9/100
# 27676/27676 [==============================] - 7s 260us/step - loss: 0.4045 - acc: 0.8107 - val_loss: 0.4074 - val_acc: 0.8072
# Epoch 10/100
# 27676/27676 [==============================] - 8s 273us/step - loss: 0.4041 - acc: 0.8127 - val_loss: 0.4054 - val_acc: 0.8078
# Epoch 11/100
# 27676/27676 [==============================] - 8s 278us/step - loss: 0.4033 - acc: 0.8118 - val_loss: 0.4070 - val_acc: 0.8066
# Train on 27676 samples, validate on 4885 samples
# Epoch 1/100
# 27676/27676 [==============================] - 8s 286us/step - loss: 0.4317 - acc: 0.7978 - val_loss: 0.4163 - val_acc: 0.8045
# Epoch 2/100
# 27676/27676 [==============================] - 7s 260us/step - loss: 0.4157 - acc: 0.8068 - val_loss: 0.4114 - val_acc: 0.8090
# Epoch 3/100
# 27676/27676 [==============================] - 7s 257us/step - loss: 0.4124 - acc: 0.8087 - val_loss: 0.4105 - val_acc: 0.8063
# Epoch 4/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.4095 - acc: 0.8108 - val_loss: 0.4048 - val_acc: 0.8102
# Epoch 5/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.4079 - acc: 0.8109 - val_loss: 0.4061 - val_acc: 0.8088
# Epoch 6/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.4066 - acc: 0.8107 - val_loss: 0.4097 - val_acc: 0.8125
# Epoch 7/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.4055 - acc: 0.8104 - val_loss: 0.4060 - val_acc: 0.8135
# Epoch 8/100
# 27676/27676 [==============================] - 7s 255us/step - loss: 0.4047 - acc: 0.8112 - val_loss: 0.4065 - val_acc: 0.8111
# Epoch 9/100
# 27676/27676 [==============================] - 7s 262us/step - loss: 0.4035 - acc: 0.8123 - val_loss: 0.4080 - val_acc: 0.8074
